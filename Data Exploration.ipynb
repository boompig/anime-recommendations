# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# %% [markdown]
# I exported my own MAL data around the middle of August 2022. The default format is XML.

# %%
path = 'data/animelist_1660694258_-_14855571.xml'

# %%
tree = ET.parse(path)
tree

# %%
root = tree.getroot()

# %% [markdown]
# The XML is structured as follows:
# - myanimelist (root)
#     - myinfo
#     - anime
#     - anime
#     - ...
#     - anime
#
# So we want the anime nodes

# %%
# see this stackoverflow answer: https://stackoverflow.com/questions/7684333/converting-xml-to-dictionary-using-elementtree

from collections import defaultdict


def etree_to_dict(t):
    d = {t.tag: {} if t.attrib else None}
    children = list(t)
    if children:
        dd = defaultdict(list)
        for dc in map(etree_to_dict, children):
            for k, v in dc.items():
                dd[k].append(v)
        d = {t.tag: {k: v[0] if len(v) == 1 else v
                     for k, v in dd.items()}}
    if t.attrib:
        d[t.tag].update(('@' + k, v)
                        for k, v in t.attrib.items())
    if t.text:
        text = t.text.strip()
        if children or t.attrib:
            if text:
                d[t.tag]['#text'] = text
        else:
            d[t.tag] = text
    return d

# %%
d = etree_to_dict(root)

# %%
len(d['myanimelist']['anime'])
# Out:
# 318

# %%
a = d['myanimelist']['anime'][0]
a
# Out:
# {'series_animedb_id': '48',
#  'series_title': '.hack//Sign',
#  'series_type': 'TV',
#  'series_episodes': '26',
#  'my_id': '0',
#  'my_watched_episodes': '0',
#  'my_start_date': '0000-00-00',
#  'my_finish_date': '0000-00-00',
#  'my_rated': None,
#  'my_score': '0',
#  'my_storage': None,
#  'my_storage_value': '0.00',
#  'my_status': 'Plan to Watch',
#  'my_comments': None,
#  'my_times_watched': '0',
#  'my_rewatch_value': None,
#  'my_priority': 'LOW',
#  'my_tags': None,
#  'my_rewatching': '0',
#  'my_rewatching_ep': '0',
#  'my_discuss': '1',
#  'my_sns': 'default',
#  'update_on_import': '0'}

# %%
anime = d['myanimelist']['anime']

# %%
df = pd.DataFrame(anime)

# %%
df
# Out:
#     series_animedb_id                                       series_title  \
# 0                  48                                        .hack//Sign
# 1               31646                                    3-gatsu no Lion
# 2               35180                         3-gatsu no Lion 2nd Season
# 3               36793                               3D Kanojo: Real Girl
# 4               38101                               5-toubun no Hanayome
# ..                ...                                                ...
# 313             35507    Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e
# 314             51096  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...
# 315             40911                                Yuukoku no Moriarty
# 316             23283                                  Zankyou no Terror
# 317             31245  Zutto Mae kara Suki deshita.: Kokuhaku Jikkou ...
#
#     series_type series_episodes my_id my_watched_episodes my_start_date  \
# 0            TV              26     0                   0    0000-00-00
# 1            TV              22     0                  22    0000-00-00
# 2            TV              22     0                  22    0000-00-00
# 3            TV              12     0                   2    0000-00-00
# 4            TV              12     0                  12    0000-00-00
# ..          ...             ...   ...                 ...           ...
# 313          TV              12     0                  12    0000-00-00
# 314          TV              13     0                   0    0000-00-00
# 315          TV              11     0                   3    0000-00-00
# 316          TV              11     0                   0    0000-00-00
# 317       Movie               1     0                   1    0000-00-00
#
#     my_finish_date my_rated my_score  ... my_comments my_times_watched  \
# 0       0000-00-00     None        0  ...        None                0
# 1       0000-00-00     None        8  ...        None                0
# 2       0000-00-00     None        8  ...        None                0
# 3       0000-00-00     None        4  ...        None                0
# 4       0000-00-00     None        5  ...        None                0
# ..             ...      ...      ...  ...         ...              ...
# 313     0000-00-00     None        8  ...        None                0
# 314     0000-00-00     None        0  ...        None                0
# 315     0000-00-00     None        5  ...        None                0
# 316     0000-00-00     None        0  ...        None                0
# 317     0000-00-00     None        6  ...        None                0
#
#     my_rewatch_value my_priority my_tags my_rewatching my_rewatching_ep  \
# 0               None         LOW    None             0                0
# 1               None         LOW    None             0                0
# 2               None         LOW    None             0                0
# 3               None         LOW    None             0                0
# 4               None         LOW    None             0                0
# ..               ...         ...     ...           ...              ...
# 313             None         LOW    None             0                0
# 314             None         LOW    None             0                0
# 315             None         LOW    None             0                0
# 316             None         LOW    None             0                0
# 317             None         LOW    None             0                0
#
#     my_discuss   my_sns update_on_import
# 0            1  default                0
# 1            1  default                0
# 2            1  default                0
# 3            1  default                0
# 4            1  default                0
# ..         ...      ...              ...
# 313          1  default                0
# 314          1  default                0
# 315          1  default                0
# 316          1  default                0
# 317          1  default                0
#
# [318 rows x 23 columns]

# %%
# massage the data a little
df.my_score = pd.to_numeric(df.my_score)

# %% [markdown]
# MAL assigns a score of 0 to anime that I have not rated

# %%
df[df.my_score > 0].sort_values(by='my_score', ascending=False)
# Out:
#     series_animedb_id                      series_title series_type  \
# 74               5114  Fullmetal Alchemist: Brotherhood          TV
# 145             36098         Kimi no Suizou wo Tabetai       Movie
# 58               1535                        Death Note          TV
# 144             32281                    Kimi no Na wa.       Movie
# 6               41457                                86          TV
# ..                ...                               ...         ...
# 287              4224                         Toradora!          TV
# 84                245             Great Teacher Onizuka          TV
# 143              6045                    Kimi ni Todoke          TV
# 268             14289                 Sukitte Ii na yo.          TV
# 186             41619                     Munou na Nana          TV
#
#     series_episodes my_id my_watched_episodes my_start_date my_finish_date  \
# 74               64     0                  64    0000-00-00     0000-00-00
# 145               1     0                   1    0000-00-00     0000-00-00
# 58               37     0                  37    0000-00-00     0000-00-00
# 144               1     0                   1    0000-00-00     0000-00-00
# 6                11     0                  11    0000-00-00     0000-00-00
# ..              ...   ...                 ...           ...            ...
# 287              25     0                  11    0000-00-00     0000-00-00
# 84               43     0                   0    0000-00-00     0000-00-00
# 143              25     0                   0    0000-00-00     0000-00-00
# 268              13     0                   0    0000-00-00     0000-00-00
# 186              13     0                   5    0000-00-00     0000-00-00
#
#     my_rated  my_score  ... my_comments my_times_watched my_rewatch_value  \
# 74      None        10  ...        None                0             None
# 145     None        10  ...        None                0             None
# 58      None        10  ...        None                0             None
# 144     None        10  ...        None                0             None
# 6       None        10  ...        None                0             None
# ..       ...       ...  ...         ...              ...              ...
# 287     None         1  ...        None                0             None
# 84      None         1  ...        None                0             None
# 143     None         1  ...        None                0             None
# 268     None         1  ...        None                0             None
# 186     None         1  ...        None                0             None
#
#     my_priority my_tags my_rewatching my_rewatching_ep my_discuss   my_sns  \
# 74          LOW    None             0                0          1  default
# 145         LOW    None             0                0          1  default
# 58          LOW    None             0                0          1  default
# 144         LOW    None             0                0          1  default
# 6           LOW    None             0                0          1  default
# ..          ...     ...           ...              ...        ...      ...
# 287         LOW    None             0                0          1  default
# 84          LOW    None             0                0          1  default
# 143         LOW    None             0                0          1  default
# 268         LOW    None             0                0          1  default
# 186         LOW    None             0                0          1  default
#
#     update_on_import
# 74                 0
# 145                0
# 58                 0
# 144                0
# 6                  0
# ..               ...
# 287                0
# 84                 0
# 143                0
# 268                0
# 186                0
#
# [200 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['series_animedb_id', 'series_title', 'series_type', 'series_episodes',
#        'my_id', 'my_watched_episodes', 'my_start_date', 'my_finish_date',
#        'my_rated', 'my_score', 'my_storage', 'my_storage_value', 'my_status',
#        'my_comments', 'my_times_watched', 'my_rewatch_value', 'my_priority',
#        'my_tags', 'my_rewatching', 'my_rewatching_ep', 'my_discuss', 'my_sns',
#        'update_on_import'],
#       dtype='object')

# %% [markdown]
# So I've added just over 300 anime and rated 200 of them

# %% [markdown]
# ## Using the MAL API
#
# The MAL API is public for public data such as info about shows. See this forum post: https://myanimelist.net/forum/?topicid=1973077
# The header value can be found here: https://github.com/SuperMarcus/myanimelist-api-specification

# %%
import requests

# %%
def query_mal(show_id):
    """The show's ID will be a string representing an integer"""
    
    # Android app
    MAL_CLIENT_ID = '6114d00ca681b7701d1e15fe11a4987e'
    
     # 'https://api.myanimelist.net/v2/anime/30230?fields=id,title,main_picture,alternative_titles,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,pictures,background,related_anime,related_manga,recommendations,studios,statistics' \
    url = f'https://api.myanimelist.net/v2/anime/{show_id}?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season'
    print(url)
    r = requests.get(url, headers={
        'X-MAL-Client-ID': MAL_CLIENT_ID,
    })
    return r.json()

# query_mal(23273)

# %%
# !mkdir data
# Out:
# mkdir: data: File exists

# %%
# !mkdir data/anime-info
# Out:
# mkdir: data/anime-info: File exists

# %%
import json
from collections import Counter
import os

# %%
# there are 318 anime in my watch list
# I can probably just get the data for all of them
df.shape
# Out:
# (318, 23)

# %% [markdown]
# Grab every conceivable interesting bit from MAL

# %%
def read_anime_stats(id):
    fname = f'data/anime-info/{id}.json'
    stats = {}
    with open(fname) as fp:
        stats = json.load(fp)
    return stats

def save_anime_stats(id, stats):
    fname = f'data/anime-info/{id}.json'
    with open(fname, 'w') as fp:
        json.dump(stats, fp, indent=4, sort_keys=True)

# %%
def crawl_mal(df):
    """The parameter is a dataframe which must have a row called series_animedb_id"""
    
    anime_info = {}
    
    for i, row in df.iterrows():
        id = row['series_animedb_id']
        fname = f'data/anime-info/{id}.json'
        if os.path.exists(fname):
            # print(f'Already collected info for anime {id}')
            v = read_anime_stats(id)
        else:
            v = query_mal(id)
            save_anime_stats(id, v)

        anime_info[id] = v
            
    return anime_info

anime_info = crawl_mal(df)
len(anime_info)
# Out:
# 318

# %%
k = list(anime_info.keys())[1]
anime_info[k]
# Out:
# {'alternative_titles': {'en': 'March Comes In Like a Lion',
#   'ja': '3月のライオン',
#   'synonyms': ['Sangatsu no Lion']},
#  'end_date': '2017-03-18',
#  'genres': [{'id': 53, 'name': 'Childcare'},
#   {'id': 8, 'name': 'Drama'},
#   {'id': 63, 'name': 'Iyashikei'},
#   {'id': 42, 'name': 'Seinen'},
#   {'id': 36, 'name': 'Slice of Life'},
#   {'id': 11, 'name': 'Strategy Game'}],
#  'id': 31646,
#  'main_picture': {'large': 'https://api-cdn.myanimelist.net/images/anime/6/82898l.jpg',
#   'medium': 'https://api-cdn.myanimelist.net/images/anime/6/82898.jpg'},
#  'mean': 8.39,
#  'nsfw': 'white',
#  'num_episodes': 22,
#  'num_list_users': 616594,
#  'num_scoring_users': 256533,
#  'popularity': 279,
#  'rank': 169,
#  'start_date': '2016-10-08',
#  'start_season': {'season': 'fall', 'year': 2016},
#  'status': 'finished_airing',
#  'studios': [{'id': 44, 'name': 'Shaft'}],
#  'title': '3-gatsu no Lion'}

# %%
df[df.series_animedb_id == '31646'].my_score
# Out:
# 1    8
# Name: my_score, dtype: int64

# %%
# compute the frequency of each tag in the list

def get_genre_freq(anime_info: dict, subset = None):
    # anime info should map the anime's ID to its information from MAL
    # the subset should be a set of IDs (or None)
    assert isinstance(anime_info, dict)
    
    genre_counts = Counter()

    for id, v in anime_info.items():
        if subset and id not in subset:
            continue
        # count each genre here once
        for genre in v['genres']:
            name = genre['name']
            genre_counts.setdefault(name, 0)
            genre_counts[name] += 1

    return genre_counts
            
genre_counts = get_genre_freq(anime_info)
genre_counts.most_common(20)
# Out:
# [('Romance', 154),
#  ('Drama', 131),
#  ('School', 128),
#  ('Comedy', 117),
#  ('Shounen', 69),
#  ('Action', 59),
#  ('Slice of Life', 57),
#  ('Fantasy', 53),
#  ('Supernatural', 53),
#  ('Mystery', 34),
#  ('Sci-Fi', 33),
#  ('Seinen', 33),
#  ('Psychological', 33),
#  ('Adventure', 28),
#  ('Love Polygon', 28),
#  ('Ecchi', 26),
#  ('Adult Cast', 21),
#  ('Shoujo', 20),
#  ('Harem', 20),
#  ('Suspense', 19)]

# %%
# in my dataset, Romance and Drama are over-represented
# let's say "good" for me is 8 or higher

good_anime = df[df.my_score >= 8]
len(good_anime)
# Out:
# 51

# %%
good_anime_ids = set(good_anime.series_animedb_id.values)
# good_anime_ids
good_genre_counts = get_genre_freq(anime_info, good_anime_ids)
len(good_genre_counts)
# Out:
# 41

# %%
good_genre_counts.most_common(20)
# Out:
# [('Drama', 28),
#  ('Romance', 20),
#  ('School', 16),
#  ('Slice of Life', 13),
#  ('Supernatural', 11),
#  ('Fantasy', 9),
#  ('Comedy', 9),
#  ('Action', 8),
#  ('Shounen', 8),
#  ('Mystery', 7),
#  ('Seinen', 6),
#  ('Adventure', 5),
#  ('Iyashikei', 4),
#  ('Sci-Fi', 4),
#  ('Vampire', 4),
#  ('Psychological', 4),
#  ('Love Polygon', 4),
#  ('Childcare', 3),
#  ('Military', 3),
#  ('Visual Arts', 3)]

# %%
g = pd.DataFrame(data = genre_counts.items(), columns=['genre', 'all_anime_freq']).sort_values('genre').set_index('genre')
g
# Out:
#                  all_anime_freq
# genre
# Action                       59
# Adult Cast                   21
# Adventure                    28
# Anthropomorphic               2
# Avant Garde                   4
# ...                         ...
# Time Travel                  13
# Vampire                       7
# Video Game                    4
# Visual Arts                  10
# Workplace                     6
#
# [62 rows x 1 columns]

# %%
g2 = pd.DataFrame(data=good_genre_counts.items(), columns=['genre', 'good_anime_freq']).sort_values('genre').set_index('genre')
g2.sort_values(by='good_anime_freq', ascending=False).head(10)
# Out:
#                good_anime_freq
# genre
# Drama                       28
# Romance                     20
# School                      16
# Slice of Life               13
# Supernatural                11
# Comedy                       9
# Fantasy                      9
# Action                       8
# Shounen                      8
# Mystery                      7

# %% [markdown]
# I'm surprised there are so few Mystery anime here

# %%
g2.shape
# Out:
# (41, 1)

# %%
g3 = g.join(g2).fillna(0)
g3
# Out:
#                  all_anime_freq  good_anime_freq
# genre
# Action                       59              8.0
# Adult Cast                   21              0.0
# Adventure                    28              5.0
# Anthropomorphic               2              1.0
# Avant Garde                   4              0.0
# ...                         ...              ...
# Time Travel                  13              2.0
# Vampire                       7              4.0
# Video Game                    4              0.0
# Visual Arts                  10              3.0
# Workplace                     6              0.0
#
# [62 rows x 2 columns]

# %%
g3['good_ratio'] = g3.good_anime_freq / g3.all_anime_freq
# add 1 to denominator to avoid small values dominating results
g3['good_ratio_adj'] = g3.good_anime_freq / (g3.all_anime_freq + 2)


g3.sort_values('good_ratio_adj', ascending=False).head(7)
# Out:
#                  all_anime_freq  good_anime_freq  good_ratio  good_ratio_adj
# genre
# Vampire                       7              4.0    0.571429        0.444444
# Award Winning                 1              1.0    1.000000        0.333333
# Iyashikei                    11              4.0    0.363636        0.307692
# Childcare                     9              3.0    0.333333        0.272727
# Anthropomorphic               2              1.0    0.500000        0.250000
# Visual Arts                  10              3.0    0.300000        0.250000
# Strategy Game                 7              2.0    0.285714        0.222222

# %% [markdown]
# So these are my top anime tags?

# %%
def get_english_title(id):
    return anime_info[id]['alternative_titles']['en']

# I'm not good with the Japanese titles
get_english_title('38753')
# Out:
# 'O Maidens in Your Savage Season'

# %%
def find_all_with_theme(theme):
    for id, v in anime_info.items():
        for genre in v['genres']:
            if genre['name'] == theme:
                yield (v['title'], get_english_title(id))
    
adult_cast = list(find_all_with_theme('Adult Cast'))
adult_cast
# Out:
# [('Black Lagoon', 'Black Lagoon'),
#  ('Danna ga Nani wo Itteiru ka Wakaranai Ken',
#   "I Can't Understand What My Husband Is Saying"),
#  ('Death Parade', 'Death Parade'),
#  ('Gokushufudou', 'The Way of the Househusband'),
#  ('Jin-Rou', 'Jin-Roh: The Wolf Brigade'),
#  ('Koukaku Kidoutai: Stand Alone Complex',
#   'Ghost in the Shell: Stand Alone Complex'),
#  ('Log Horizon', 'Log Horizon'),
#  ('Monster', 'Monster'),
#  ('Nana', 'Nana'),
#  ('Natsuyuki Rendezvous', 'Natsuyuki Rendezvous'),
#  ('Net-juu no Susume', 'Recovery of an MMO Junkie'),
#  ('Ookami to Koushinryou', 'Spice and Wolf'),
#  ('Paprika', 'Paprika'),
#  ('Paripi Koumei', 'Ya Boy Kongming!'),
#  ('Perfect Blue', 'Perfect Blue'),
#  ('Psycho-Pass', 'Psycho-Pass'),
#  ('Seikaisuru Kado', 'KADO: The Right Answer'),
#  ('Shirobako', 'Shirobako'),
#  ('Shouwa Genroku Rakugo Shinjuu: Sukeroku Futatabi-hen',
#   'Descending Stories: Showa Genroku Rakugo Shinju'),
#  ('Uchuu Kyoudai', 'Space Brothers'),
#  ('Wotaku ni Koi wa Muzukashii', 'Wotakoi: Love is Hard for Otaku')]

# %% [markdown]
# For some reason, Golden Time doesn't have the "Adult Cast" tag. Also Bakuman season 3. Also Golden Time, and the other university anime. And anime where the characters age in, like The Wind Rises.

# %%
list(find_all_with_theme('Award Winning'))
# Out:
# [('Sen to Chihiro no Kamikakushi', 'Spirited Away')]

# %% [markdown]
# Spirited Away is the only award winning anime on MAL?

# %%
list(find_all_with_theme('Vampire'))
# Out:
# [('Bakemonogatari', 'Bakemonogatari'),
#  ('Kizumonogatari I: Tekketsu-hen', 'Kizumonogatari Part 1: Iron-Blooded'),
#  ('Kizumonogatari II: Nekketsu-hen', 'Kizumonogatari Part 2: Hot-Blooded'),
#  ('Kizumonogatari III: Reiketsu-hen', 'Kizumonogatari Part 3: Cold-Blooded'),
#  ('Monogatari Series: Second Season', 'Monogatari Series: Second Season'),
#  ('Owarimonogatari', 'Owarimonogatari'),
#  ('Vanitas no Karte', 'The Case Study of Vanitas')]

# %% [markdown]
# It makes sense why I like Vampire films - basically every vampire anime on my list is from Monogatari

# %%
list(find_all_with_theme('Iyashikei'))
# Out:
# [('3-gatsu no Lion', 'March Comes In Like a Lion'),
#  ('3-gatsu no Lion 2nd Season', 'March Comes In Like A Lion 2nd Season'),
#  ('Acchi Kocchi', 'Place to Place'),
#  ('Aharen-san wa Hakarenai', 'Aharen-san wa Hakarenai'),
#  ('Amaama to Inazuma', 'Sweetness & Lightning'),
#  ('Barakamon', 'Barakamon'),
#  ('Flying Witch', 'Flying Witch'),
#  ('Honobono Log', ''),
#  ('Karakai Jouzu no Takagi-san 2', 'Teasing Master Takagi-san 2'),
#  ('Tanaka-kun wa Itsumo Kedaruge', 'Tanaka-kun is Always Listless'),
#  ('Usagi Drop', 'Bunny Drop')]

# %% [markdown]
# How the f is 3-gatsu a healing anime??

# %%
list(find_all_with_theme('Mystery'))
# Out:
# [('.hack//Sign', '.hack//Sign'),
#  ('Ajin', 'Ajin: Demi-Human'),
#  ('Another', 'Another'),
#  ('Bakemonogatari', 'Bakemonogatari'),
#  ('Boku dake ga Inai Machi', 'ERASED'),
#  ('ef: A Tale of Memories.', 'ef - a tale of memories.'),
#  ('Gosick', ''),
#  ('Great Pretender', ''),
#  ('Higashi no Eden', 'Eden of The East'),
#  ('Houseki no Kuni', 'Land of the Lustrous'),
#  ('Hyouka', 'Hyouka'),
#  ('Kaiba', 'Kaiba'),
#  ('Kakegurui', 'Kakegurui'),
#  ('Kizumonogatari II: Nekketsu-hen', 'Kizumonogatari Part 2: Hot-Blooded'),
#  ('Kizumonogatari III: Reiketsu-hen', 'Kizumonogatari Part 3: Cold-Blooded'),
#  ('Monogatari Series: Second Season', 'Monogatari Series: Second Season'),
#  ('Monster', 'Monster'),
#  ('Nisemonogatari', 'Nisemonogatari'),
#  ('Odd Taxi', 'Odd Taxi'),
#  ('Owarimonogatari', 'Owarimonogatari'),
#  ('Paprika', 'Paprika'),
#  ('Sakurada Reset', 'Sagrada Reset'),
#  ('Serial Experiments Lain', 'Serial Experiments Lain'),
#  ('Shinsekai yori', 'From the New World'),
#  ('Summertime Render', 'Summer Time Rendering'),
#  ('Suzumiya Haruhi no Shoushitsu', 'The Disappearance of Haruhi Suzumiya'),
#  ('Suzumiya Haruhi no Yuuutsu', 'The Melancholy of Haruhi Suzumiya'),
#  ('Suzumiya Haruhi no Yuuutsu (2009)',
#   'The Melancholy of Haruhi Suzumiya Season 2'),
#  ('Witch Hunter Robin', 'Witch Hunter Robin'),
#  ('Yakusoku no Neverland', 'The Promised Neverland'),
#  ('Yamada-kun to 7-nin no Majo', 'Yamada-kun and the Seven Witches'),
#  ('Yojouhan Shinwa Taikei', 'The Tatami Galaxy'),
#  ('Yuukoku no Moriarty', 'Moriarty the Patriot'),
#  ('Zankyou no Terror', 'Terror in Resonance')]

# %%
# how is this not a mystery?
anime_info['37450']
# Out:
# {'alternative_titles': {'en': 'Rascal Does Not Dream of Bunny Girl Senpai',
#   'ja': '青春ブタ野郎はバニーガール先輩の夢を見ない',
#   'synonyms': ['AoButa']},
#  'end_date': '2018-12-27',
#  'genres': [{'id': 4, 'name': 'Comedy'},
#   {'id': 8, 'name': 'Drama'},
#   {'id': 22, 'name': 'Romance'},
#   {'id': 23, 'name': 'School'},
#   {'id': 37, 'name': 'Supernatural'}],
#  'id': 37450,
#  'main_picture': {'large': 'https://api-cdn.myanimelist.net/images/anime/1301/93586l.jpg',
#   'medium': 'https://api-cdn.myanimelist.net/images/anime/1301/93586.jpg'},
#  'mean': 8.26,
#  'nsfw': 'white',
#  'num_episodes': 13,
#  'num_list_users': 1502209,
#  'num_scoring_users': 961555,
#  'popularity': 54,
#  'rank': 267,
#  'start_date': '2018-10-04',
#  'start_season': {'season': 'fall', 'year': 2018},
#  'status': 'finished_airing',
#  'studios': [{'id': 1835, 'name': 'CloverWorks'}],
#  'title': 'Seishun Buta Yarou wa Bunny Girl Senpai no Yume wo Minai'}

# %% [markdown]
# ## Biggest Controversial Picks
#
# What anime do I like that others dislike?

# %%
# for every anime for which I have a rating, extract that rating
rated_df = df[df.my_score > 0].copy()
rated_df.shape
# Out:
# (200, 23)

# %%
# OK we have a rating for 200 anime
pd.unique(rated_df.my_status)
# Out:
# array(['Completed', 'Dropped', 'On-Hold', 'Watching'], dtype=object)

# %% [markdown]
# I rated a few anime that I haven't finished watching. Let's see what those are.

# %%
rated_df[rated_df.my_status == 'Watching']
# Out:
#     series_animedb_id       series_title series_type series_episodes my_id  \
# 269             47194  Summertime Render          TV              25     0
#
#     my_watched_episodes my_start_date my_finish_date my_rated  my_score  ...  \
# 269                  14    0000-00-00     0000-00-00     None         9  ...
#
#     my_comments my_times_watched my_rewatch_value my_priority my_tags  \
# 269        None                0             None         LOW    None
#
#     my_rewatching my_rewatching_ep my_discuss   my_sns update_on_import
# 269             0                0          1  default                0
#
# [1 rows x 23 columns]

# %%
rated_df[rated_df.my_status == 'On-Hold']
# Out:
#     series_animedb_id    series_title series_type series_episodes my_id  \
# 234             34102  Sakurada Reset          TV              24     0
#
#     my_watched_episodes my_start_date my_finish_date my_rated  my_score  ...  \
# 234                   4    0000-00-00     0000-00-00     None         5  ...
#
#     my_comments my_times_watched my_rewatch_value my_priority my_tags  \
# 234        None                0             None         LOW    None
#
#     my_rewatching my_rewatching_ep my_discuss   my_sns update_on_import
# 234             0                0          0  default                0
#
# [1 rows x 23 columns]

# %% [markdown]
# I think that's fine

# %%
mean_rating = rated_df.series_animedb_id.apply(lambda id: anime_info[id]['mean'])
mean_rating
# Out:
# 1      8.39
# 2      8.95
# 3      6.84
# 4      7.68
# 5      8.11
#        ...
# 308    8.04
# 310    7.57
# 313    7.86
# 315    8.15
# 317    7.23
# Name: series_animedb_id, Length: 200, dtype: float64

# %%
rated_df['mean_rating'] = mean_rating

# %%
rated_df['rating_diff'] = rated_df.my_score - rated_df.mean_rating

# %% [markdown]
# These are the shows I most overvalue relative to actual rating.

# %%
rated_df.sort_values('rating_diff', ascending=False).head(20)\
[['series_animedb_id', 'series_title', 'my_score', 'mean_rating', 'rating_diff']]
# Out:
#     series_animedb_id                                       series_title  \
# 6               41457                                                 86
# 26              38753                  Araburu Kisetsu no Otome-domo yo.
# 100               578                                     Hotaru no Haka
# 145             36098                          Kimi no Suizou wo Tabetai
# 58               1535                                         Death Note
# 300             18245                                      White Album 2
# 244             23273                            Shigatsu wa Kimi no Uso
# 241               199                      Sen to Chihiro no Kamikakushi
# 144             32281                                     Kimi no Na wa.
# 105             12189                                             Hyouka
# 140             16662                                       Kaze Tachinu
# 74               5114                   Fullmetal Alchemist: Brotherhood
# 280              2236                              Toki wo Kakeru Shoujo
# 237             37450  Seishun Buta Yarou wa Bunny Girl Senpai no Yum...
# 276             38826                                        Tenki no Ko
# 37              31043                            Boku dake ga Inai Machi
# 261             48736                    Sono Bisque Doll wa Koi wo Suru
# 29               5081                                     Bakemonogatari
# 148             22535                         Kiseijuu: Sei no Kakuritsu
# 97              33241                                       Honobono Log
#
#      my_score  mean_rating  rating_diff
# 6          10         8.25         1.75
# 26          9         7.37         1.63
# 100        10         8.50         1.50
# 145        10         8.56         1.44
# 58         10         8.62         1.38
# 300         9         7.63         1.37
# 244        10         8.66         1.34
# 241        10         8.78         1.22
# 144        10         8.86         1.14
# 105         9         8.09         0.91
# 140         9         8.10         0.90
# 74         10         9.13         0.87
# 280         9         8.13         0.87
# 237         9         8.26         0.74
# 276         9         8.31         0.69
# 37          9         8.31         0.69
# 261         9         8.33         0.67
# 29          9         8.34         0.66
# 148         9         8.35         0.65
# 97          8         7.35         0.65

# %% [markdown]
# No surprise these are the shows that I rated 9 or 10. Since very few shows on MAL ever cross the 9 barrier, those picks are bound to create a large absolute difference.

# %%
def relative_diff(row):
    return (row.my_score - row.mean_rating) / row.mean_rating

rated_df['relative_diff'] = rated_df.apply(relative_diff, axis=1)

# %%
rated_df['en_title'] = rated_df.series_animedb_id.apply(get_english_title)

# %%
rated_df.sort_values('relative_diff', ascending=False).head(20)\
[['series_animedb_id', 'series_title', 'en_title', 'my_score', 'mean_rating', 'rating_diff', 'relative_diff']]
# Out:
#     series_animedb_id                                       series_title  \
# 26              38753                  Araburu Kisetsu no Otome-domo yo.
# 6               41457                                                 86
# 300             18245                                      White Album 2
# 100               578                                     Hotaru no Haka
# 145             36098                          Kimi no Suizou wo Tabetai
# 58               1535                                         Death Note
# 244             23273                            Shigatsu wa Kimi no Uso
# 241               199                      Sen to Chihiro no Kamikakushi
# 144             32281                                     Kimi no Na wa.
# 105             12189                                             Hyouka
# 140             16662                                       Kaze Tachinu
# 280              2236                              Toki wo Kakeru Shoujo
# 74               5114                   Fullmetal Alchemist: Brotherhood
# 237             37450  Seishun Buta Yarou wa Bunny Girl Senpai no Yum...
# 97              33241                                       Honobono Log
# 227             38992    Rikei ga Koi ni Ochita no de Shoumei shitemita.
# 37              31043                            Boku dake ga Inai Machi
# 276             38826                                        Tenki no Ko
# 261             48736                    Sono Bisque Doll wa Koi wo Suru
# 277             47159            Tensai Ouji no Akaji Kokka Saisei Jutsu
#
#                                               en_title  my_score  mean_rating  \
# 26                     O Maidens in Your Savage Season         9         7.37
# 6                                        86 Eighty Six        10         8.25
# 300                                      White Album 2         9         7.63
# 100                             Grave of the Fireflies        10         8.50
# 145                        I Want To Eat Your Pancreas        10         8.56
# 58                                          Death Note        10         8.62
# 244                                  Your Lie in April        10         8.66
# 241                                      Spirited Away        10         8.78
# 144                                         Your Name.        10         8.86
# 105                                             Hyouka         9         8.09
# 140                                     The Wind Rises         9         8.10
# 280                    The Girl Who Leapt Through Time         9         8.13
# 74                    Fullmetal Alchemist: Brotherhood        10         9.13
# 237         Rascal Does Not Dream of Bunny Girl Senpai         9         8.26
# 97                                                             8         7.35
# 227       Science Fell in Love, So I Tried to Prove It         8         7.37
# 37                                              ERASED         9         8.31
# 276                                Weathering with You         9         8.31
# 261                                My Dress-Up Darling         9         8.33
# 277  The Genius Prince's Guide to Raising a Nation ...         8         7.41
#
#      rating_diff  relative_diff
# 26          1.63       0.221167
# 6           1.75       0.212121
# 300         1.37       0.179554
# 100         1.50       0.176471
# 145         1.44       0.168224
# 58          1.38       0.160093
# 244         1.34       0.154734
# 241         1.22       0.138952
# 144         1.14       0.128668
# 105         0.91       0.112485
# 140         0.90       0.111111
# 280         0.87       0.107011
# 74          0.87       0.095290
# 237         0.74       0.089588
# 97          0.65       0.088435
# 227         0.63       0.085482
# 37          0.69       0.083032
# 276         0.69       0.083032
# 261         0.67       0.080432
# 277         0.59       0.079622

# %% [markdown]
# This is way more interesting, but clearly weighted towards my 10s. Some of my ratings in retrospect are hard to defened here.

# %% [markdown]
# The better question is what do I think is decent that MAL really doesn't like (anything below a 7 on MAL may as well be trash)?

# %%
rated_df[(rated_df.my_score >= 7) & (rated_df.mean_rating < 7)]
# Out:
# Empty DataFrame
# Columns: [series_animedb_id, series_title, series_type, series_episodes, my_id, my_watched_episodes, my_start_date, my_finish_date, my_rated, my_score, my_storage, my_storage_value, my_status, my_comments, my_times_watched, my_rewatch_value, my_priority, my_tags, my_rewatching, my_rewatching_ep, my_discuss, my_sns, update_on_import, mean_rating, rating_diff]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# Absolutely nothing. What about lower-rated selections?

# %%
rated_df[(rated_df.my_score >= 8) & (rated_df.mean_rating < 7.5)]\
[['series_animedb_id', 'series_title', 'en_title', 'my_score', 'mean_rating', 'rating_diff', 'relative_diff']]
# Out:
#     series_animedb_id                                     series_title  \
# 26              38753                Araburu Kisetsu no Otome-domo yo.
# 97              33241                                     Honobono Log
# 227             38992  Rikei ga Koi ni Ochita no de Shoumei shitemita.
# 277             47159          Tensai Ouji no Akaji Kokka Saisei Jutsu
#
#                                               en_title  my_score  mean_rating  \
# 26                     O Maidens in Your Savage Season         9         7.37
# 97                                                             8         7.35
# 227       Science Fell in Love, So I Tried to Prove It         8         7.37
# 277  The Genius Prince's Guide to Raising a Nation ...         8         7.41
#
#      rating_diff  relative_diff
# 26          1.63       0.221167
# 97          0.65       0.088435
# 227         0.63       0.085482
# 277         0.59       0.079622

# %% [markdown]
# I stand by these opinions. These shows are good.

# %% [markdown]
# ### most trollish opinions
#
# Now for the other direction. I think this is going to be a bunch of Tsundere bullshit

# %%
rated_df.sort_values('rating_diff').head(20)\
[['series_animedb_id', 'series_title', 'en_title', 'my_score', 'mean_rating', 'rating_diff', 'relative_diff']]
# Out:
#     series_animedb_id                             series_title  \
# 84                245                    Great Teacher Onizuka
# 287              4224                                Toradora!
# 126              7054                    Kaichou wa Maid-sama!
# 143              6045                           Kimi ni Todoke
# 130              8525                 Kami nomi zo Shiru Sekai
# 268             14289                        Sukitte Ii na yo.
# 186             41619                            Munou na Nana
# 284             14227                   Tonari no Kaibutsu-kun
# 229             23277             Saenai Heroine no Sodatekata
# 142               147                      Kimi ga Nozomu Eien
# 275             32093            Tanaka-kun wa Itsumo Kedaruge
# 51              34382                                   Citrus
# 175             20785              Mahouka Koukou no Rettousei
# 179             20541                  Mikakunin de Shinkoukei
# 106             42361                 Ijiranaide, Nagatoro-san
# 178               330                           Midori no Hibi
# 171             35677                          Liz to Aoi Tori
# 96              36296                         Hinamatsuri (TV)
# 160             50631  Komi-san wa, Comyushou desu. 2nd Season
# 5               39783                   5-toubun no Hanayome ∬
#
#                                       en_title  my_score  mean_rating  \
# 84                       Great Teacher Onizuka         1         8.69
# 287                                  Toradora!         1         8.10
# 126                                 Maid Sama!         1         8.01
# 143             Kimi ni Todoke: From Me to You         1         8.00
# 130                   The World God Only Knows         1         7.67
# 268                          Say "I Love You."         1         7.43
# 186                            Talentless Nana         1         7.20
# 284                          My Little Monster         2         7.49
# 229  Saekano: How to Raise a Boring Girlfriend         2         7.49
# 142                            Rumbling Hearts         2         7.20
# 275              Tanaka-kun is Always Listless         3         7.85
# 51                                      Citrus         2         6.47
# 175         The Irregular at Magic High School         3         7.43
# 179                Engaged to the Unidentified         3         7.39
# 106           Don't Toy with Me, Miss Nagatoro         3         7.37
# 178                                Midori Days         3         7.24
# 171                      Liz and the Blue Bird         4         8.19
# 96                                 Hinamatsuri         4         8.16
# 160            Komi Can't Communicate Season 2         4         8.15
# 5             The Quintessential Quintuplets 2         4         8.11
#
#      rating_diff  relative_diff
# 84         -7.69      -0.884925
# 287        -7.10      -0.876543
# 126        -7.01      -0.875156
# 143        -7.00      -0.875000
# 130        -6.67      -0.869622
# 268        -6.43      -0.865410
# 186        -6.20      -0.861111
# 284        -5.49      -0.732977
# 229        -5.49      -0.732977
# 142        -5.20      -0.722222
# 275        -4.85      -0.617834
# 51         -4.47      -0.690881
# 175        -4.43      -0.596231
# 179        -4.39      -0.594046
# 106        -4.37      -0.592944
# 178        -4.24      -0.585635
# 171        -4.19      -0.511600
# 96         -4.16      -0.509804
# 160        -4.15      -0.509202
# 5          -4.11      -0.506782

# %% [markdown]
# I stand by everything I wrote here. These are all bad.

# %% [markdown]
# ## other people's MAL
#
# There may be some bias in my MAL (list). So to normalize let's get some other people's lists.

# %%
# !mkdir data/other-peoples-lists
# Out:
# mkdir: data/other-peoples-lists: File exists

# %%
def save_anime_list(username: str, d: dict):
    with open(f'data/other-peoples-lists/{username}.json', 'w') as fp:
        json.dump(d, fp, indent=4, sort_keys=True)
        
def read_anime_list(username: str) -> dict:
    d = {}
    with open(f'data/other-peoples-lists/{username}.json') as fp:
        d = json.load(fp)
    return d

def fetch_other_user_list(username, limit=400):
    MAL_CLIENT_ID = '6114d00ca681b7701d1e15fe11a4987e'
    # url = f'https://api.myanimelist.net/v2/users/{username}/animelist?fields=list_status&limit={limit}&status=completed'
    # only fetch completed anime
    url = f'https://api.myanimelist.net/v2/users/{username}/animelist?fields=list_status&limit={limit}'
    print(url)
    r = requests.get(url, headers={
        'X-MAL-Client-ID': MAL_CLIENT_ID,
    })
    anime_list = r.json()
    save_anime_list(username, anime_list)
    return anime_list

# %%
usernames = [
#     randos on reddit
    'chiliehead',
    'RiverSorcerer',
#     me
    'mister_baseball',
    'Nomar_95',
]

for username in usernames:
    fname = f'data/other-peoples-lists/{username}.json'
    if not os.path.exists(fname):
        fetch_other_user_list(username)
    else:
        print('already fetched')
# Out:
# already fetched
# already fetched
# already fetched
# already fetched

# %%
# few more usernames
# LeonKevlar does stitches
for username in ['awspear', 'Aochhi', '20thcbnow', 'aniMayor', 'Blueserphant', 'Kendots', 'scot911', 'LeonKevlar', 'marcopolos059']:
    fname = f'data/other-peoples-lists/{username}.json'
    if not os.path.exists(fname):
        fetch_other_user_list(username)
    else:
        print('already fetched')
# Out:
# already fetched
# already fetched
# already fetched
# already fetched
# already fetched
# already fetched
# already fetched
# already fetched
# already fetched

# %%
other_lists = {}

for fname in os.listdir('data/other-peoples-lists'):
    username, ext = os.path.splitext(fname)
    if username != 'mister_baseball':
        other_lists[username] = read_anime_list(username)
    print(username)
    
len(other_lists)
# Out:
# Nomar_95
# RiverSorcerer
# LeonKevlar
# chiliehead
# marcopolos059
# mister_baseball
# Aochhi
# aniMayor
# 20thcbnow
# Blueserphant
# Kendots
# awspear
# scot911
# 12

# %% [markdown]
# The result has these main fields
#
# - data -> a list
#     - each entry has elements list_status and node
#         - node has information about the actual anime. We care about the id
# - paging

# %%
other_lists['LeonKevlar']['data'][0]['node']
# Out:
# {'id': 41380,
#  'main_picture': {'large': 'https://api-cdn.myanimelist.net/images/anime/1506/117717l.jpg',
#   'medium': 'https://api-cdn.myanimelist.net/images/anime/1506/117717.jpg'},
#  'title': '100-man no Inochi no Ue ni Ore wa Tatteiru'}

# %%
all_ids = Counter()

for username, other_list in other_lists.items():
    for anime in other_list['data']:
        id = anime['node']['id']
        all_ids.setdefault(id, 0)
        all_ids[id] += 1

# for each item
all_ids.most_common(20)
# Out:
# [(8676, 11),
#  (6547, 11),
#  (24833, 11),
#  (2251, 11),
#  (889, 11),
#  (31964, 11),
#  (33486, 11),
#  (1575, 11),
#  (1, 11),
#  (10087, 11),
#  (31646, 10),
#  (41457, 10),
#  (41433, 10),
#  (477, 10),
#  (5081, 10),
#  (31043, 10),
#  (2167, 10),
#  (790, 10),
#  (11741, 10),
#  (5114, 10)]

# %%
all_ids
# Out:
# Counter({3914: 3,
#          31646: 10,
#          35180: 6,
#          28789: 2,
#          38101: 7,
#          39783: 3,
#          48548: 2,
#          41457: 10,
#          48569: 6,
#          32998: 9,
#          49: 2,
#          33337: 7,
#          39610: 1,
#          11759: 7,
#          311: 4,
#          313: 2,
#          314: 2,
#          312: 2,
#          39790: 8,
#          39093: 1,
#          1292: 4,
#          32977: 2,
#          36904: 3,
#          38815: 1,
#          34881: 8,
#          101: 6,
#          31580: 2,
#          33253: 1,
#          30123: 8,
#          31173: 5,
#          283: 4,
#          22199: 9,
#          25013: 7,
#          47: 7,
#          40054: 3,
#          36864: 6,
#          16201: 5,
#          41433: 10,
#          19429: 2,
#          22729: 5,
#          27655: 2,
#          1177: 7,
#          17901: 2,
#          8676: 11,
#          11235: 5,
#          9925: 6,
#          22147: 7,
#          2356: 2,
#          24531: 2,
#          6547: 11,
#          10067: 2,
#          5251: 4,
#          3080: 3,
#          9989: 9,
#          11111: 8,
#          24833: 11,
#          30654: 8,
#          9919: 6,
#          33506: 4,
#          38753: 8,
#          7647: 9,
#          9074: 1,
#          477: 10,
#          29893: 2,
#          48411: 1,
#          41674: 2,
#          962: 5,
#          3297: 6,
#          4772: 1,
#          2563: 2,
#          28249: 5,
#          40128: 6,
#          1205: 3,
#          36214: 9,
#          2402: 7,
#          2921: 3,
#          37171: 8,
#          66: 8,
#          32827: 5,
#          37525: 6,
#          2251: 11,
#          3901: 5,
#          40964: 4,
#          35965: 6,
#          6347: 8,
#          5081: 10,
#          7674: 4,
#          10030: 3,
#          12365: 2,
#          36649: 7,
#          22789: 8,
#          39195: 6,
#          49469: 1,
#          40935: 4,
#          32311: 1,
#          57: 5,
#          9513: 4,
#          10218: 2,
#          12113: 2,
#          12115: 2,
#          50248: 5,
#          52229: 2,
#          530: 5,
#          740: 2,
#          532: 1,
#          1239: 1,
#          996: 1,
#          68: 3,
#          34572: 6,
#          37498: 3,
#          1520: 2,
#          1373: 1,
#          1521: 1,
#          889: 11,
#          4901: 3,
#          1519: 5,
#          12079: 1,
#          7059: 1,
#          11285: 1,
#          36308: 3,
#          269: 4,
#          1686: 2,
#          2889: 2,
#          4835: 3,
#          762: 1,
#          41467: 1,
#          834: 1,
#          34618: 7,
#          11633: 3,
#          150: 4,
#          49596: 2,
#          40060: 5,
#          31043: 10,
#          31964: 11,
#          33486: 11,
#          36456: 9,
#          38408: 6,
#          41587: 5,
#          49918: 2,
#          36896: 4,
#          38699: 1,
#          39565: 2,
#          33929: 3,
#          35459: 4,
#          16405: 1,
#          10719: 7,
#          14967: 4,
#          1690: 4,
#          369: 3,
#          37451: 5,
#          35072: 1,
#          34566: 2,
#          28755: 1,
#          32365: 1,
#          4177: 5,
#          6772: 2,
#          8514: 1,
#          9252: 1,
#          9465: 1,
#          9724: 1,
#          10092: 1,
#          14345: 6,
#          31478: 6,
#          32867: 4,
#          41468: 5,
#          1657: 5,
#          10163: 3,
#          12293: 3,
#          232: 5,
#          372: 3,
#          35320: 3,
#          10012: 6,
#          37435: 5,
#          4981: 5,
#          3087: 5,
#          44511: 4,
#          978: 1,
#          28999: 8,
#          10800: 9,
#          59: 4,
#          37338: 3,
#          14741: 7,
#          35608: 6,
#          18671: 6,
#          2274: 2,
#          2768: 2,
#          2167: 10,
#          4181: 9,
#          6351: 6,
#          4059: 6,
#          1818: 3,
#          34437: 1,
#          1575: 11,
#          34438: 1,
#          34439: 1,
#          34440: 1,
#          2904: 9,
#          11703: 1,
#          31147: 4,
#          38940: 5,
#          10029: 5,
#          514: 4,
#          1: 11,
#          5: 6,
#          4037: 2,
#          42310: 3,
#          20031: 7,
#          1482: 2,
#          61: 1,
#          2724: 5,
#          34103: 1,
#          32189: 1,
#          33028: 1,
#          16592: 5,
#          26349: 6,
#          29067: 5,
#          16355: 2,
#          11843: 9,
#          2025: 9,
#          7338: 2,
#          35849: 7,
#          15583: 6,
#          974: 5,
#          6880: 6,
#          14353: 4,
#          34497: 4,
#          1535: 9,
#          28223: 8,
#          40056: 8,
#          33988: 8,
#          2164: 6,
#          235: 2,
#          6438: 1,
#          24169: 1,
#          3702: 3,
#          35120: 7,
#          2354: 3,
#          2355: 3,
#          2397: 2,
#          51638: 2,
#          38668: 8,
#          37520: 9,
#          38145: 6,
#          38691: 8,
#          48549: 2,
#          50612: 3,
#          40852: 6,
#          223: 6,
#          225: 4,
#          987: 1,
#          6033: 2,
#          22777: 1,
#          11359: 1,
#          892: 1,
#          893: 1,
#          30694: 2,
#          36946: 2,
#          48903: 1,
#          898: 1,
#          901: 1,
#          903: 1,
#          905: 1,
#          906: 1,
#          14837: 1,
#          25389: 1,
#          985: 1,
#          5152: 1,
#          31339: 6,
#          28121: 8,
#          37347: 6,
#          40454: 4,
#          47164: 2,
#          6746: 9,
#          27833: 5,
#          23199: 4,
#          27831: 4,
#          236: 1,
#          42192: 4,
#          50002: 1,
#          41361: 4,
#          39792: 8,
#          226: 9,
#          37033: 4,
#          790: 10,
#          32901: 5,
#          36792: 4,
#          393: 1,
#          2759: 5,
#          3784: 4,
#          3785: 4,
#          3786: 4,
#          6702: 4,
#          22043: 2,
#          12049: 1,
#          30778: 1,
#          35972: 1,
#          34662: 4,
#          33047: 4,
#          37651: 3,
#          34321: 3,
#          38084: 4,
#          40206: 2,
#          14829: 7,
#          27525: 3,
#          20509: 3,
#          31706: 3,
#          34100: 3,
#          38897: 2,
#          12565: 3,
#          356: 5,
#          25537: 7,
#          33049: 6,
#          33050: 4,
#          6922: 2,
#          22297: 9,
#          28701: 9,
#          31389: 5,
#          27821: 8,
#          10087: 11,
#          11741: 10,
#          227: 9,
#          35842: 3,
#          33010: 4,
#          51304: 1,
#          32979: 8,
#          18507: 2,
#          9367: 4,
#          120: 4,
#          38680: 7,
#          40417: 2,
#          42938: 2,
#          41120: 5,
#          71: 7,
#          72: 4,
#          121: 5,
#          5114: 10,
#          7902: 1,
#          908: 2,
#          664: 1,
#          430: 2,
#          9135: 4,
#          41025: 7,
#          49709: 1,
#          8187: 5,
#          32948: 8,
#          1251: 4,
#          126: 2,
#          2890: 5,
#          1281: 7,
#          30825: 1,
#          24765: 9,
#          35222: 5,
#          239: 6,
#          18229: 2,
#          28907: 7,
#          31637: 4,
#          1829: 3,
#          23289: 7,
#          41710: 6,
#          49930: 4,
#          2321: 4,
#          16918: 4,
#          820: 6,
#          3016: 3,
#          42886: 4,
#          31433: 5,
#          51805: 3,
#          36369: 3,
#          36370: 3,
#          36371: 3,
#          3014: 4,
#          1301: 1,
#          1140: 3,
#          918: 7,
#          7472: 3,
#          15335: 4,
#          9969: 3,
#          15417: 3,
#          25313: 2,
#          34096: 4,
#          35843: 4,
#          36838: 4,
#          37491: 4,
#          6945: 2,
#          39486: 3,
#          44087: 3,
#          28977: 6,
#          32366: 4,
#          37349: 5,
#          47160: 2,
#          39576: 4,
#          4872: 1,
#          21431: 3,
#          268: 5,
#          1760: 3,
#          4039: 3,
#          1761: 1,
#          4639: 4,
#          8425: 8,
#          42984: 2,
#          48: 3,
#          1901: 4,
#          32601: 3,
#          33419: 1,
#          51464: 2,
#          49520: 5,
#          42847: 2,
#          48553: 5,
#          49979: 1,
#          32828: 7,
#          31080: 5,
#          51614: 1,
#          43756: 2,
#          37873: 2,
#          49123: 1,
#          40854: 1,
#          50854: 2,
#          1214: 2,
#          40752: 4,
#          46352: 4,
#          47639: 2,
#          47917: 1,
#          52578: 2,
#          51371: 2,
#          1536: 2,
#          5356: 3,
#          4975: 2,
#          40960: 3,
#          37914: 4,
#          35756: 6,
#          51680: 1,
#          48702: 3,
#          52505: 1,
#          6573: 2,
#          10418: 2,
#          48779: 3,
#          51916: 1,
#          50281: 2,
#          35823: 3,
#          49515: 2,
#          8624: 1,
#          10444: 1,
#          48542: 1,
#          52701: 2,
#          8408: 4,
#          52081: 2,
#          50481: 2,
#          38062: 5,
#          51417: 5,
#          51293: 1,
#          3167: 5,
#          50999: 2,
#          31376: 7,
#          5684: 1,
#          6527: 1,
#          48649: 1,
#          33731: 6,
#          34280: 4,
#          240: 3,
#          34213: 4,
#          39533: 3,
#          14811: 2,
#          28669: 2,
#          21273: 4,
#          29787: 2,
#          10793: 4,
#          411: 1,
#          387: 4,
#          20689: 4,
#          413: 3,
#          9931: 2,
#          48857: 2,
#          40610: 2,
#          7645: 2,
#          23269: 2,
#          38476: 3,
#          49154: 1,
#          8074: 3,
#          135: 1,
#          36296: 5,
#          37614: 3,
#          20853: 3,
#          24231: 1,
#          42897: 3,
#          38276: 2,
#          12189: 4,
#          51711: 1,
#          40046: 3,
#          9938: 1,
#          160: 3,
#          34420: 2,
#          38472: 3,
#          52367: 1,
#          34012: 2,
#          48804: 2,
#          49438: 2,
#          38790: 2,
#          40530: 1,
#          36906: 2,
#          38383: 1,
#          42994: 1,
#          39049: 1,
#          40661: 1,
#          9001: 1,
#          39534: 1,
#          228: 1,
#          1594: 1,
#          3713: 1,
#          46569: 1,
#          47250: 2,
#          26441: 2,
#          5680: 4,
#          48316: 1,
#          48775: 1,
#          50685: 1,
#          42822: 1,
#          7054: 2,
#          49385: 1,
#          489: 2,
#          16009: 2,
#          39198: 4,
#          43969: 2,
#          1530: 3,
#          2593: 5,
#          3782: 4,
#          45613: 2,
#          40908: 2,
#          33: 3,
#          38000: 3,
#          6045: 2,
#          33218: 1,
#          32281: 4,
#          36098: 4,
#          50796: 1,
#          16732: 2,
#          33034: 1,
#          41471: 1,
#          51213: 1,
#          34290: 1,
#          35206: 1,
#          22535: 3,
#          33206: 4,
#          39247: 2,
#          35363: 1,
#          28851: 4,
#          39388: 2,
#          31091: 1,
#          146: 1,
#          52173: 1,
#          467: 2,
#          1566: 1,
#          801: 1,
#          50590: 1,
#          49776: 2,
#          32949: 2,
#          13655: 2,
#          18195: 1,
#          17265: 4,
#          15051: 3,
#          19111: 1,
#          20745: 1,
#          41169: 1,
#          24997: 1,
#          39071: 3,
#          34599: 3,
#          252: 1,
#          14513: 1,
#          276: 2,
#          39585: 1,
#          2791: 1,
#          30705: 1,
#          42590: 1,
#          10721: 3,
#          21603: 1,
#          38778: 2,
#          10620: 3,
#          35078: 1,
#          2235: 1,
#          2581: 2,
#          3927: 1,
#          6288: 1,
#          82: 1,
#          6336: 1,
#          31251: 2,
#          33051: 1,
#          81: 2,
#          49828: 1,
#          30014: 1,
#          17074: 3,
#          30307: 1,
#          49376: 1,
#          50923: 1,
#          52092: 1,
#          3641: 1,
#          877: 3,
#          50582: 1,
#          8496: 1,
#          15689: 3,
#          30: 3,
#          32: 3,
#          31404: 1,
#          31953: 2,
#          34914: 2,
#          1210: 3,
#          46422: 1,
#          11597: 3,
#          584: 2,
#          272: 1,
#          52274: 1,
#          17549: 3,
#          40178: 2,
#          46102: 3,
#          50653: 1,
#          52611: 1,
#          21557: 1,
#          30276: 3,
#          32013: 1,
#          33949: 1,
#          51705: 1,
#          34262: 1,
#          29803: 2,
#          35073: 1,
#          50380: 1,
#          42627: 1,
#          437: 3,
#          329: 3,
#          10711: 2,
#          13601: 3,
#          165: 2,
#          35298: 1,
#          25859: 1,
#          34561: 2,
#          11491: 1,
#          13377: 1,
#          32262: 1,
#          51403: 1,
#          36513: 2,
#          52461: 1,
#          64: 2,
#          48363: 1,
#          44807: 1,
#          20709: 1,
#          48414: 1,
#          48761: 1,
#          51837: 1,
#          529: 1,
#          12531: 2,
#          34839: 1,
#          31564: 2,
#          23987: 1,
#          2605: 1,
#          2476: 1,
#          167: 1,
#          400: 1,
#          42826: 1,
#          51215: 1,
#          49304: 1,
#          37450: 1,
#          11751: 1,
#          32843: 1,
#          38787: 1,
#          339: 1,
#          38759: 1,
#          43439: 1,
#          355: 1,
#          2787: 1,
#          6773: 1,
#          6572: 1,
#          52347: 1,
#          34240: 1,
#          44074: 1,
#          2216: 1,
#          38015: 1,
#          44037: 1,
#          21843: 1,
#          47257: 1,
#          49849: 1,
#          13125: 1,
#          46093: 1,
#          47162: 1,
#          35838: 1,
#          2923: 1,
#          33433: 1,
#          42923: 1,
#          50416: 1,
#          40586: 1,
#          50738: 1,
#          45425: 1,
#          35540: 1,
#          6802: 1,
#          1965: 1,
#          48849: 1,
#          48736: 1,
#          35839: 1,
#          50209: 1,
#          2582: 1,
#          1602: 1,
#          198: 1,
#          51252: 1,
#          50265: 1,
#          50602: 1,
#          8934: 1,
#          38578: 1,
#          9893: 1,
#          5681: 1,
#          36817: 1,
#          40685: 1,
#          1577: 1,
#          32093: 1,
#          15125: 1,
#          38610: 1,
#          2001: 1,
#          49891: 1,
#          16436: 1,
#          50760: 1,
#          26: 1,
#          567: 1,
#          6213: 1,
#          16049: 1,
#          4654: 1,
#          8937: 1,
#          6211: 1,
#          41589: 1,
#          42249: 1,
#          52305: 1,
#          37579: 1,
#          41389: 1,
#          6: 1,
#          52093: 1,
#          44191: 1,
#          49426: 1,
#          50652: 1,
#          95: 1,
#          49533: 1,
#          49766: 1,
#          40620: 1,
#          32924: 1,
#          856: 1,
#          181: 1,
#          48580: 1,
#          37521: 1,
#          33352: 1,
#          14283: 1,
#          30355: 1,
#          37682: 1,
#          38999: 1,
#          1023: 1,
#          43299: 1,
#          41380: 3,
#          44881: 3,
#          35248: 2,
#          40679: 1,
#          40148: 4,
#          36793: 4,
#          37956: 3,
#          33964: 1,
#          9611: 1,
#          50: 5,
#          880: 2,
#          2198: 1,
#          3090: 1,
#          25397: 4,
#          12291: 5,
#          37403: 4,
#          1533: 2,
#          15061: 5,
#          17082: 4,
#          37561: 3,
#          103: 1,
#          12149: 3,
#          34051: 3,
#          33839: 2,
#          36001: 2,
#          34350: 4,
#          9117: 3,
#          15951: 2,
#          12669: 2,
#          31771: 4,
#          9062: 2,
#          35834: 3,
#          35015: 5,
#          37206: 4,
#          35427: 5,
#          31519: 2,
#          33746: 2,
#          19759: 1,
#          21995: 3,
#          11737: 1,
#          10647: 1,
#          18893: 2,
#          40532: 4,
#          36882: 4,
#          40507: 2,
#          51473: 2,
#          31821: 2,
#          12581: 1,
#          37996: 3,
#          6166: 6,
#          38572: 5,
#          40550: 4,
#          9736: 3,
#          104: 2,
#          38328: 6,
#          40930: 5,
#          286: 2,
#          36873: 4,
#          8516: 3,
#          30795: 4,
#          495: 2,
#          2705: 1,
#          288: 2,
#          34636: 4,
#          32664: 4,
#          33573: 2,
#          37869: 2,
#          37870: 1,
#          42892: 1,
#          36516: 3,
#          38020: 2,
#          37716: 5,
#          39221: 2,
#          10396: 6,
#          31904: 4,
#          27727: 1,
#          13535: 4,
#          9544: 1,
#          3446: 1,
#          31853: 1,
#          48585: 1,
#          10490: 1,
#          14027: 2,
#          10897: 2,
#          9907: 2,
#          21405: 6,
#          40904: 2,
#          38186: 5,
#          40004: 3,
#          39819: 3,
#          33080: 1,
#          1347: 3,
#          33475: 2,
#          1689: 5,
#          36828: 2,
#          371: 1,
#          33354: 1,
#          1078: 2,
#          12187: 2,
#          15927: 2,
#          34525: 3,
#          30485: 1,
#          34753: 1,
#          33771: 2,
#          14397: 7,
#          18745: 1,
#          37379: 5,
#          35821: 5,
#          1069: 1,
#          16157: 4,
#          39523: 4,
#          38226: 2,
#          27601: 4,
#          16934: 3,
#          34382: 4,
#          32407: 1,
#          8728: 2,
#          12685: 2,
#          5163: 1,
#          31456: 2,
#          37823: 2,
#          22839: 2,
#          36976: 2,
#          2907: 2,
#          62: 2,
#          39681: 4,
#          31636: 3,
#          36049: 2,
#          30127: 4,
#          38656: 3,
#          19163: 4,
#          22961: 2,
#          36633: 3,
#          41461: 2,
#          24655: 3,
#          52196: 2,
#          17641: 3,
#          43814: 1,
#          24031: 4,
#          9379: 4,
#          5177: 3,
#          35928: 1,
#          32271: 2,
#          36524: 2,
#          41074: 1,
#          31163: 4,
#          10155: 3,
#          46604: 3,
#          37982: 3,
#          36525: 2,
#          30346: 5,
#          813: 4,
#          40526: 4,
#          39026: 6,
#          32887: 4,
#          32801: 3,
#          48470: 2,
#          38544: 2,
#          788: 2,
#          38671: 6,
#          40956: 3,
#          39063: 4,
#          39811: 1,
#          48997: 4,
#          44248: 2,
#          36064: 1,
#          36914: 1,
#          41497: 2,
#          31056: 2,
#          25011: 2,
#          33456: 2,
#          36833: 2,
#          19109: 2,
#          18851: 3,
#          13183: 2,
#          13263: 2,
#          317: 1,
#          408: 1,
#          34427: 1,
#          32696: 3,
#          33203: 1,
#          31931: 1,
#          73: 2,
#          37188: 3,
#          123: 5,
#          33743: 4,
#          4725: 4,
#          34855: 3,
#          48760: 4,
#          36317: 3,
#          30544: 3,
#          40358: 3,
#          36144: 2,
#          127: 1,
#          128: 1,
#          32455: 1,
#          2508: 1,
#          18465: 1,
#          19159: 1,
#          1813: 1,
#          129: 2,
#          132: 2,
#          34481: 2,
#          32607: 5,
#          24855: 1,
#          14131: 5,
#          241: 4,
#          37998: 2,
#          39463: 4,
#          51478: 1,
#          20707: 1,
#          25627: 1,
#          7669: 1,
#          8481: 1,
#          6408: 2,
#          38045: 1,
#          6076: 1,
#          35025: 1,
#          33363: 1,
#          35632: 1,
#          37843: 1,
#          34595: 1,
#          37626: 1,
#          41090: 1,
#          38748: 1,
#          38603: 1,
#          298: 1,
#          29978: 2,
#          11755: 1,
#          32737: 1,
#          28761: 2,
#          6060: 1,
#          36745: 1,
#          36746: 2,
#          36747: 1,
#          39208: 1,
#          48976: 1,
#          5133: 1,
#          48352: 1,
#          1549: 1,
#          6682: 3,
#          23579: 1,
#          48858: 2,
#          30234: 1,
#          28339: 1,
#          15527: 1,
#          49005: 1,
#          9624: 1,
#          300: 3,
#          3685: 1,
#          30665: 1,
#          38869: 1,
#          ...})

# %%
other_anime_df = pd.DataFrame(data=all_ids.items(), columns=['series_animedb_id', 'count'])
other_anime_df
# Out:
#       series_animedb_id  count
# 0                  3914      3
# 1                 31646     10
# 2                 35180      6
# 3                 28789      2
# 4                 38101      7
# ...                 ...    ...
# 2299              14653      1
# 2300              16982      1
# 2301               9958      1
# 2302              23153      1
# 2303               5521      1
#
# [2304 rows x 2 columns]

# %%
crawl_mal(other_anime_df)
# Out:
# https://api.myanimelist.net/v2/anime/30694?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/36946?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48903?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/898?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/901?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/903?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/905?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/906?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/14837?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/25389?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/985?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/5152?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/31339?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40454?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/47164?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6746?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/27833?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/23199?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/27831?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/236?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/42192?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/50002?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/41361?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37033?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/790?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/32901?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/36792?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/393?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/2759?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3784?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3785?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3786?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6702?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/22043?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/12049?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/30778?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/35972?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34662?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/33047?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37651?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34321?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/38084?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40206?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/14829?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/27525?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/20509?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/31706?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34100?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/38897?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/12565?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/25537?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/33049?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/33050?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6922?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/28701?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/31389?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/27821?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/10087?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/11741?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/35842?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/33010?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51304?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/32979?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/9367?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/120?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40417?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/42938?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/41120?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/71?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/72?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/7902?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/908?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/664?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/430?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/9135?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/41025?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/49709?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/8187?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1251?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/126?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/2890?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1281?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/30825?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/24765?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/35222?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/239?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/18229?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/28907?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/31637?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1829?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/2321?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/16918?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/820?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3016?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/42886?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/31433?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51805?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/36369?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/36370?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/36371?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3014?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1301?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1140?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/918?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/7472?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/15335?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/9969?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/15417?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/25313?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34096?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/35843?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/36838?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37491?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6945?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/39486?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/44087?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/28977?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/32366?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37349?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/47160?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/39576?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/4872?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/21431?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/268?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1760?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/4039?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1761?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/4639?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/42984?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1901?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/32601?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/33419?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51464?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/42847?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48553?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/49979?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/31080?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51614?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/43756?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37873?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/49123?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40854?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/50854?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1214?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40752?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/47639?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/47917?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/52578?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51371?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1536?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/5356?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/4975?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40960?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37914?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/35756?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51680?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48702?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/52505?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6573?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/10418?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48779?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51916?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/50281?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/35823?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/49515?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/8624?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/10444?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48542?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/52701?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/8408?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/52081?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/50481?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/38062?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51417?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51293?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3167?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/50999?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/5684?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6527?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48649?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/33731?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/240?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34213?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/39533?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/14811?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/28669?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/21273?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/29787?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/10793?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/411?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/387?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/20689?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/413?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/9931?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48857?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40610?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/7645?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/23269?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/38476?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/49154?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/8074?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/135?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37614?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/20853?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/24231?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/38276?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/51711?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/40046?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/9938?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/160?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34420?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/38472?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/52367?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34012?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48804?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/49438?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/38790?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/36906?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# ...
# https://api.myanimelist.net/v2/anime/50055?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/28831?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/20365?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/11701?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/34611?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/39890?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/15423?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/49052?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1051?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/28391?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/33814?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/30205?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/7193?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6164?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/10901?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/15133?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1586?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1327?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3306?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/20471?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/29999?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1233?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/8701?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/5673?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/937?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/54?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/22677?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/9737?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/10447?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/6032?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1202?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/7786?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/2825?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/2576?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/35709?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1961?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/16518?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1596?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1488?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/11697?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1028?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/2837?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/2839?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/22271?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/37195?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/791?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/16261?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/42163?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/4567?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1079?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/492?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/493?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/19233?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/50515?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/1497?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/48992?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# https://api.myanimelist.net/v2/anime/3401?fields=id,title,genres,alternative_titles,start_date,end_date,mean,studios,rank,popularity,num_list_users,num_scoring_users,nsfw,status,my_list_status,num_episodes,start_season
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/opt/anaconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/opt/anaconda3/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/opt/anaconda3/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 crawl_mal(other_anime_df)
#
# Input In [25], in crawl_mal(df)
#      11     v = read_anime_stats(id)
#      12 else:
# ---> 13     v = query_mal(id)
#      14     save_anime_stats(id, v)
#      16 anime_info[id] = v
#
# Input In [19], in query_mal(show_id)
#       9 print(url)
#      10 r = requests.get(url, headers={
#      11     'X-MAL-Client-ID': MAL_CLIENT_ID,
#      12 })
# ---> 13 return r.json()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value] <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <TITLE>ERROR: The request could not be satisfied</TITLE>
# </HEAD><BODY>
# <H1>403 ERROR</H1>
# <H2>The request could not be satisfied.</H2>
# <HR noshade size="1px">
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <BR clear="all">
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <BR clear="all">
# <HR noshade size="1px">
# <PRE>
# Generated by cloudfront (CloudFront)
# Request ID: b328_BKkUOlyjj5Vsb37F9kovJWVXmoH2gXBZ5xM-w-K-XrOjVLCeA==
# </PRE>
# <ADDRESS>
# </ADDRESS>
# </BODY></HTML>: 0
